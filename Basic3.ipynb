# %%
#Q1
my_tuple = {"jayant","harsh,","gaurav","hemant","parth"}
for i in my_tuple:
    print(i)
# Out:
# harsh,
# hemant
# parth
# gaurav
# jayant

# %%
#Q2
print(len(my_tuple))
# Out:
# 5

# %%
#Q3
