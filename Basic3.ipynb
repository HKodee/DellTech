# %%
#Q1
my_tuple = {"jayant","harsh,","gaurav","hemant","parth"}
for i in my_tuple:
    print(i)
# Out:
# harsh,
# hemant
# parth
# gaurav
# jayant

# %%
#Q2
print(len(my_tuple))
# Out:
# 5

# %%
#Q3
def count_frequency(x):
    count=0
    for i in my_tuple:
        if (i==x):
            count=+1        
    print(count)
    
count_frequency(my_tuple[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 9
#       5         if (i==x):
#       6             count=+1
#       7     print(count)
#       8
# ----> 9 count_frequency(my_tuple[1])
#      10
#      11
#
# TypeError: 'set' object is not subscriptable

# %%
#Q4

def check(x):
    if x in my_tuple:
        print("element in tuple")
        
    else:
        print("not found")

# %%
#Q5
numbers=[10,20,30,40]
nw_tuple = tuple(numbers)
